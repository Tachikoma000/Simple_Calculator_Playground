# %%
# Import all necessary libraries
import urllib.parse # url parser for hippo data source
import math # Needed for basic math operations",
import pandas as pd # Needed fpr dataframe creation and operations\n",
import numpy as np # Needed for array manipulations\n",
from itertools import islice # Needed for more complex row and coloumn slicing\n",
import matplotlib.pyplot as plt # Needed for quickly ploting results"
import plotly.express as px # cleaner graph library
import plotly.graph_objects as go # cleaner graph library
import dash_core_components as dcc # ui development 
import dash_html_components as html # ui development
from dash.dependencies import Input, Output #ui development

# %%
sheet_id = "13alTGGKZyotRR3R1VFNlkL0uZ6GoKjmK8TjVZ1ZQyvQ" # the google spreadsheet id
sheet_name = "Protocol%20Metrics" # the specific sheet of interest
sheet_name_2 = "Protocol%20Metrics-Historical" # hippo also has another sheet for historical data from August 4th till now
url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(sheet_id, sheet_name) #contruct url
url2 = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(sheet_id, sheet_name_2)

# %%
pd.read_csv(url)
# Out:
#            timestamp       block ohmCirculatingSupply sOhmCirculatingSupply  \
# 0  9/4/2021 16:28:01  13,160,270            1,461,176             1,315,631
#
#   totalSupply ohmPrice     marketCap totalValueLocked treasuryRiskFreeValue  \
# 0   1,786,378  $317.42  $463,809,517     $417,610,297           $39,042,794
#
#   treasuryMarketValue  ...  runway10k runway20k runway50k runway70k  \
# 0        $111,904,835  ...        269       234       199       189
#
#   runway100k runwayCurrent treasuryOhmDaiPOL treasuryOhmFraxPOL          id  \
# 0        179           279         99.705011          99.882155  1630713600
#
#    rawTheGraphDailyTimestamp
# 0           9/4/2021 0:21:26
#
# [1 rows x 29 columns]

# %%
pd.read_csv(url2)
# Out:
#            timestamp       block ohmCirculatingSupply sOhmCirculatingSupply  \
# 0  9/4/2021 16:28:01  13,160,270            1,461,176             1,315,631
#
#   totalSupply ohmPrice     marketCap totalValueLocked treasuryRiskFreeValue  \
# 0   1,786,378  $317.42  $463,809,517     $417,610,297           $39,042,794
#
#   treasuryMarketValue  ...  runway10k runway20k runway50k runway70k  \
# 0        $111,904,835  ...        269       234       199       189
#
#   runway100k runwayCurrent treasuryOhmDaiPOL treasuryOhmFraxPOL          id  \
# 0        179           279         99.705011          99.882155  1630713600
#
#    rawTheGraphDailyTimestamp
# 0           9/4/2021 0:21:26
#
# [1 rows x 29 columns]
